# %% [markdown]
# # Demo de Extracción desde Socrata
#
# En este notebook se muestra paso a paso cómo utilizar la clase `SocrataDatasetLoader` para extraer datos de Socrata, aplicar validaciones de gobernanza y calidad, y registrar la metadata asociada al proceso.
#
# Cada celda está comentada para que puedas entender el propósito y el funcionamiento de cada paso.

# %% [markdown]
# ## Librerias

# %%
# Importamos las librerías y módulos necesarios.
from sodapy import Socrata
import sys
import yaml

# %% [markdown]
# ### Configuración del entorno de ejecución

# %%
from config.notebook_location import find_project_root

# %%
# Definir el nombre del directorio del proyecto
project_name = "personal-library"

# Encontrar la raíz del proyecto
project_root = find_project_root(project_name)

# Agregar la raíz del proyecto al principio de sys.path para facilitar las importaciones
sys.path.insert(0, project_root)
print("Project root added to sys.path:", project_root)
# Out:
# Project root added to sys.path: d:\Espacios de trabajo\personal-library

# %% [markdown]
# ### Librerías personales

# %%
# Importamos las clases definidas en nuestro sistema de ingesta.
from ingestion.sources.from_socrata import SocrataDatasetLoader
from ingestion.governance.engine import GovernanceEngine
from ingestion.governance.engine_policy_autogen import get_or_create_policy
from ingestion.governance.metrics import MetricsEngine
from ingestion.base.metadata_logger import MetadataLogger
from ingestion.governance.remediation import RemediationEngine
from ingestion.governance.intelligent_improvement import IntelligentImprovementEngine

# %% [markdown]
# ## Proceso de ingesta de los datos

# %%
# Inicializar el logger de metadatos
meta_logger = MetadataLogger(report_path="demos/reports/demo_socrata.parquet")

# %% [markdown]
# **1. Inicialización del Cliente Socrata**
#
# Se crea una instancia del cliente de Socrata apuntando al dominio de datos. En este ejemplo, usamos "www.datos.gov.co".
# Si tu dataset requiere autenticación, provee las credenciales necesarias (aquí se usa `None` como placeholder).

# %%
# Inicializamos el cliente de Socrata.
client = Socrata("www.datos.gov.co", None)
# Out:
# 2025-03-29 18:30:07,980 - root - WARNING - Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# **2. Configuración del Loader y Extracción de Datos**
#
# Se crea una instancia de `SocrataDatasetLoader` y se utiliza para extraer datos de un dataset específico.
# - **dataset_code:** Código del dataset en Socrata.
# - **filters:** Filtros de consulta; en este ejemplo, extraemos registros donde `fecha_de_firma` es mayor o igual a "2023-01-01".
# - **limit:** Número máximo de registros a extraer.

# %%
# Creamos la instancia del loader para Socrata.
loader = SocrataDatasetLoader(client)

# %%
# Definimos los parámetros para la extracción.
dataset_code = "jbjy-vk9h"  # Código del dataset en Socrata
filters = {"fecha_de_firma": (">=", "2023-01-01")}
limit = 100

# %%
meta_logger.log({
    "step": "data_extraction",
    "source": "Socrata",
    "dataset_code": dataset_code,
    "filters": filters,
    "limit": limit,
    "status": "started"
})
# Out:
# 2025-03-29 18:37:19,445 - ingestion.base.metadata_logger - DEBUG - Logged metadata: {'step': 'data_extraction', 'source': 'Socrata', 'dataset_code': 'jbjy-vk9h', 'filters': {'fecha_de_firma': ('>=', '2023-01-01')}, 'limit': 100, 'status': 'started', 'uuid': '922889f7-64ec-4a29-bcea-604a65fb2f9d', 'timestamp': '2025-03-29T22:37:19.444448+00:00'}

# %%
# Realizamos la carga de datos.
df = loader.load_data(dataset_code=dataset_code, filters=filters, limit=limit)

# Mostramos las primeras filas del DataFrame extraído.
df.head(2)
# Out:
# 2025-03-29 18:30:11,024 - ingestion.sources.from_socrata - DEBUG - Executing query: SELECT * WHERE fecha_de_firma >= '2023-01-01' LIMIT 100
# 2025-03-29 18:30:11,035 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): www.datos.gov.co:443
# 2025-03-29 18:30:12,898 - urllib3.connectionpool - DEBUG - https://www.datos.gov.co:443 "GET /resource/jbjy-vk9h.json?%24query=SELECT+%2A+WHERE+fecha_de_firma+%3E%3D+%272023-01-01%27+LIMIT+100 HTTP/1.1" 200 None
# 2025-03-29 18:30:13,218 - ingestion.sources.from_socrata - INFO - Loaded 100 rows from dataset jbjy-vk9h
#                                       nombre_entidad nit_entidad departamento  \
# 0             HOSPITAL SAN JUAN DE DIOS DE HONDA ESE   890700666       Tolima
# 1  HOSPITAL DE CASTILLA LA NUEVA EMPRESA SOCIAL D...   900004059         Meta
#
#               ciudad                          localizaci_n        orden  \
# 0              Honda            Colombia,  Tolima ,  Honda  Territorial
# 1  Castilla La Nueva  Colombia,  Meta ,  Castilla La Nueva  Territorial
#
#                       sector                  rama entidad_centralizada  \
# 0  Salud y Protección Social  Corporación Autónoma      Descentralizada
# 1  Salud y Protección Social  Corporación Autónoma      Descentralizada
#
#   proceso_de_compra  ...      nombre_ordenador_del_gasto  \
# 0  CO1.BDOS.3681223  ...  MANUEL ALFONSO GONZaLEZ CANTOR
# 1  CO1.BDOS.3690528  ...      ROSA MARIA JIMENEZ BAQUERO
#
#   tipo_de_documento_ordenador_del_gasto  \
# 0                  Cédula de Ciudadanía
# 1                  Cédula de Ciudadanía
#
#   n_mero_de_documento_ordenador_del_gasto            nombre_supervisor  \
# 0                                79393172  MARTHA LUCIA OSORIO RAMIREZ
# 1                                40370893     LUIS ENRIQUE BARON TELLO
#
#   tipo_de_documento_supervisor n_mero_de_documento_supervisor  \
# 0         Cédula de Ciudadanía                       38281318
# 1         Cédula de Ciudadanía                     1121827353
#
#   nombre_ordenador_de_pago tipo_de_documento_ordenador_de_pago  \
# 0              No definido                         No definido
# 1              No definido                         No definido
#
#   n_mero_de_documento_ordenador_de_pago fecha_de_notificaci_n_de_prorrogaci_n
# 0                           No definido                                   NaN
# 1                           No definido                                   NaN
#
# [2 rows x 85 columns]

# %%
meta_logger.log({
    "step": "data_extraction",
    "record_count": len(df),
    "status": "completed"
})
# Out:
# 2025-03-29 18:37:35,488 - ingestion.base.metadata_logger - DEBUG - Logged metadata: {'step': 'data_extraction', 'record_count': 100, 'status': 'completed', 'uuid': '029fa1d4-5aef-4604-8072-93bf29bc0688', 'timestamp': '2025-03-29T22:37:35.488826+00:00'}

# %% [markdown]
# **3. Carga de la Política de Gobernanza**
#
# La política define las reglas de calidad y gobernabilidad que se aplicarán al dataset.
#
# Se carga desde un archivo YAML. Asegúrate de que el archivo `s2_contracts.yaml` exista en la ruta indicada.

# %%
policy = get_or_create_policy(df, "s2_contracts.yaml")
# Out:
# [INFO] Policy 's2_contracts.yaml' not found. Generating default...
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')
# d:\Espacios de trabajo\personal-library\ingestion\governance\engine_policy_autogen.py:155: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(col, errors='raise')

# %%
# Imprimimos la política cargada para verificar su contenido.
print("Política de Gobernanza Cargada:")
print(yaml.dump(policy, sort_keys=False, allow_unicode=True))
# Out:
# Política de Gobernanza Cargada:
# dataset_metadata:
#   columns: 85
#   rows_sampled: 100
#   generated_by: default_policy_generator
#   generated_on: '2025-03-29T22:30:23.876640Z'
#   data_source: inferred
#   schema_version: '1.0'
#   language: undetected
# compliance:
#   compliance_frameworks:
#   - GDPR
#   risk_level: high
# enforcement_requirements:
#   mandatory_rules:
#   - no_nulls
#   - valid_date_format
#   required_fields: []
#   privacy_enforcement: medium
#   security_baseline: masked
#   allowed_transparency:
#   - internal
#   - public
#   risk_acceptance: medium
#   framework_enforcement:
#   - GDPR
# fields:
# - field_name: nombre_entidad
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_entidad' classified as string with privacy=high based
#     on naming and content analysis.
# - field_name: nit_entidad
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nit_entidad' classified as integer with privacy=high based
#     on naming and content analysis.
# - field_name: departamento
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'departamento' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: ciudad
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'ciudad' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: localizaci_n
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'localizaci_n' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: orden
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'orden' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: sector
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'sector' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: rama
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'rama' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: entidad_centralizada
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'entidad_centralizada' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: proceso_de_compra
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'proceso_de_compra' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: id_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'id_contrato' classified as string with privacy=high based
#     on naming and content analysis.
# - field_name: referencia_del_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'referencia_del_contrato' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: estado_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'estado_contrato' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: codigo_de_categoria_principal
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'codigo_de_categoria_principal' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: descripcion_del_proceso
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'descripcion_del_proceso' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: tipo_de_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_contrato' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: modalidad_de_contratacion
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'modalidad_de_contratacion' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: justificacion_modalidad_de
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'justificacion_modalidad_de' classified as string with privacy=high
#     based on naming and content analysis.
# - field_name: fecha_de_firma
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_de_firma' classified as datetime with privacy=low based
#     on naming and content analysis.
# - field_name: fecha_de_inicio_del_contrato
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_de_inicio_del_contrato' classified as datetime with
#     privacy=low based on naming and content analysis.
# - field_name: fecha_de_fin_del_contrato
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_de_fin_del_contrato' classified as datetime with privacy=low
#     based on naming and content analysis.
# - field_name: condiciones_de_entrega
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'condiciones_de_entrega' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: tipodocproveedor
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipodocproveedor' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: documento_proveedor
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'documento_proveedor' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: proveedor_adjudicado
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'proveedor_adjudicado' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: es_grupo
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'es_grupo' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: es_pyme
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'es_pyme' classified as string with privacy=low based on naming
#     and content analysis.
# - field_name: habilita_pago_adelantado
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'habilita_pago_adelantado' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: liquidaci_n
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'liquidaci_n' classified as string with privacy=high based
#     on naming and content analysis.
# - field_name: obligaci_n_ambiental
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'obligaci_n_ambiental' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: obligaciones_postconsumo
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'obligaciones_postconsumo' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: reversion
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'reversion' classified as string with privacy=low based on
#     naming and content analysis.
# - field_name: origen_de_los_recursos
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'origen_de_los_recursos' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: destino_gasto
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'destino_gasto' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: valor_del_contrato
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_del_contrato' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: valor_de_pago_adelantado
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_de_pago_adelantado' classified as integer with privacy=low
#     based on naming and content analysis.
# - field_name: valor_facturado
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_facturado' classified as integer with privacy=high based
#     on naming and content analysis.
# - field_name: valor_pendiente_de_pago
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_pendiente_de_pago' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: valor_pagado
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_pagado' classified as integer with privacy=high based
#     on naming and content analysis.
# - field_name: valor_amortizado
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_amortizado' classified as integer with privacy=low based
#     on naming and content analysis.
# - field_name: valor_pendiente_de
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_pendiente_de' classified as integer with privacy=low
#     based on naming and content analysis.
# - field_name: valor_pendiente_de_ejecucion
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'valor_pendiente_de_ejecucion' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: estado_bpin
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'estado_bpin' classified as string with privacy=low based on
#     naming and content analysis.
# - field_name: c_digo_bpin
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'c_digo_bpin' classified as string with privacy=low based on
#     naming and content analysis.
# - field_name: anno_bpin
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'anno_bpin' classified as string with privacy=low based on
#     naming and content analysis.
# - field_name: saldo_cdp
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'saldo_cdp' classified as integer with privacy=high based on
#     naming and content analysis.
# - field_name: saldo_vigencia
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'saldo_vigencia' classified as integer with privacy=low based
#     on naming and content analysis.
# - field_name: espostconflicto
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'espostconflicto' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: dias_adicionados
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'dias_adicionados' classified as integer with privacy=low based
#     on naming and content analysis.
# - field_name: puntos_del_acuerdo
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'puntos_del_acuerdo' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: pilares_del_acuerdo
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'pilares_del_acuerdo' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: urlproceso
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'urlproceso' classified as string with privacy=high based on
#     naming and content analysis.
# - field_name: nombre_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_representante_legal' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: nacionalidad_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nacionalidad_representante_legal' classified as string with
#     privacy=high based on naming and content analysis.
# - field_name: domicilio_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'domicilio_representante_legal' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: tipo_de_identificaci_n_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_identificaci_n_representante_legal' classified as
#     string with privacy=high based on naming and content analysis.
# - field_name: identificaci_n_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'identificaci_n_representante_legal' classified as string with
#     privacy=high based on naming and content analysis.
# - field_name: g_nero_representante_legal
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'g_nero_representante_legal' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: presupuesto_general_de_la_nacion_pgn
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'presupuesto_general_de_la_nacion_pgn' classified as integer
#     with privacy=low based on naming and content analysis.
# - field_name: sistema_general_de_participaciones
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'sistema_general_de_participaciones' classified as integer
#     with privacy=high based on naming and content analysis.
# - field_name: sistema_general_de_regal_as
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'sistema_general_de_regal_as' classified as integer with privacy=low
#     based on naming and content analysis.
# - field_name: recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_'
#     classified as integer with privacy=high based on naming and content analysis.
# - field_name: recursos_de_credito
#   type: integer
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'recursos_de_credito' classified as integer with privacy=low
#     based on naming and content analysis.
# - field_name: recursos_propios
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'recursos_propios' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: ultima_actualizacion
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: false
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'ultima_actualizacion' classified as datetime with privacy=low
#     based on naming and content analysis.
# - field_name: codigo_entidad
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'codigo_entidad' classified as integer with privacy=high based
#     on naming and content analysis.
# - field_name: codigo_proveedor
#   type: integer
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: true
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: true
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'codigo_proveedor' classified as integer with privacy=high
#     based on naming and content analysis.
# - field_name: fecha_inicio_liquidacion
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: false
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_inicio_liquidacion' classified as datetime with privacy=high
#     based on naming and content analysis.
# - field_name: fecha_fin_liquidacion
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: false
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags:
#   - GDPR
#   data_subject: true
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_fin_liquidacion' classified as datetime with privacy=high
#     based on naming and content analysis.
# - field_name: objeto_del_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'objeto_del_contrato' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: duraci_n_del_contrato
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'duraci_n_del_contrato' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: nombre_del_banco
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_del_banco' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: tipo_de_cuenta
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_cuenta' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: n_mero_de_cuenta
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'n_mero_de_cuenta' classified as string with privacy=high based
#     on naming and content analysis.
# - field_name: el_contrato_puede_ser_prorrogado
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'el_contrato_puede_ser_prorrogado' classified as string with
#     privacy=low based on naming and content analysis.
# - field_name: nombre_ordenador_del_gasto
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_ordenador_del_gasto' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: tipo_de_documento_ordenador_del_gasto
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_documento_ordenador_del_gasto' classified as string
#     with privacy=low based on naming and content analysis.
# - field_name: n_mero_de_documento_ordenador_del_gasto
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'n_mero_de_documento_ordenador_del_gasto' classified as string
#     with privacy=high based on naming and content analysis.
# - field_name: nombre_supervisor
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_supervisor' classified as string with privacy=low based
#     on naming and content analysis.
# - field_name: tipo_de_documento_supervisor
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_documento_supervisor' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: n_mero_de_documento_supervisor
#   type: string
#   required: true
#   rules: []
#   privacy_level: high
#   security: encrypted
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: restricted
#   retention_policy: default
#   critical_field: false
#   justification: Field 'n_mero_de_documento_supervisor' classified as string with
#     privacy=high based on naming and content analysis.
# - field_name: nombre_ordenador_de_pago
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'nombre_ordenador_de_pago' classified as string with privacy=low
#     based on naming and content analysis.
# - field_name: tipo_de_documento_ordenador_de_pago
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'tipo_de_documento_ordenador_de_pago' classified as string
#     with privacy=low based on naming and content analysis.
# - field_name: n_mero_de_documento_ordenador_de_pago
#   type: string
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: true
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'n_mero_de_documento_ordenador_de_pago' classified as string
#     with privacy=low based on naming and content analysis.
# - field_name: fecha_de_notificaci_n_de_prorrogaci_n
#   type: datetime
#   required: true
#   rules: []
#   privacy_level: low
#   security: none
#   transparency: internal
#   integrity:
#     unique: false
#     no_nulls: false
#     consistent_format: true
#     contains_outliers: false
#   compliance_tags: []
#   data_subject: false
#   access_restriction: public
#   retention_policy: default
#   critical_field: false
#   justification: Field 'fecha_de_notificaci_n_de_prorrogaci_n' classified as datetime
#     with privacy=low based on naming and content analysis.

# %% [markdown]
# **4. Validación del Dataset con el Motor de Gobernanza**
#
# Se utiliza la clase `GovernanceEngine` para aplicar las validaciones definidas en la política al DataFrame.
#
# Se generan reportes que incluyen errores y advertencias detectadas en la ingesta.

# %%
# Crea una instancia del engine usando el nombre de política deseado
engine = GovernanceEngine(df, "s2_contracts.yaml")
    
# Ejecuta las validaciones y muestra las advertencias
warnings = engine.run_policy_checks()
if warnings:
    print("Warnings generated by GovernanceEngine:")
    for w in warnings:
        print(" -", w)
else:
    print("No warnings. The dataset complies with the policy.")
# Out:
# Warnings generated by GovernanceEngine:
#  - {'field': 'nombre_entidad', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_entidad', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nit_entidad', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nit_entidad', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nit_entidad', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'departamento', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'departamento', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'departamento', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ciudad', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ciudad', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ciudad', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'localizaci_n', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'localizaci_n', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'localizaci_n', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'orden', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'orden', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'orden', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sector', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sector', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sector', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'rama', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'rama', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'rama', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'entidad_centralizada', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'entidad_centralizada', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'proceso_de_compra', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'proceso_de_compra', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'id_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'id_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'referencia_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'referencia_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_de_categoria_principal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_de_categoria_principal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'descripcion_del_proceso', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'descripcion_del_proceso', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'descripcion_del_proceso', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'modalidad_de_contratacion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'modalidad_de_contratacion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'justificacion_modalidad_de', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'justificacion_modalidad_de', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_firma', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_firma', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_firma', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_firma', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_inicio_del_contrato', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_inicio_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_inicio_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_inicio_del_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_fin_del_contrato', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_fin_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_fin_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_fin_del_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'condiciones_de_entrega', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'condiciones_de_entrega', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'condiciones_de_entrega', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipodocproveedor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipodocproveedor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipodocproveedor', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'documento_proveedor', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'documento_proveedor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'documento_proveedor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'proveedor_adjudicado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'proveedor_adjudicado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'proveedor_adjudicado', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_grupo', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_grupo', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_grupo', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_pyme', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_pyme', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'es_pyme', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'habilita_pago_adelantado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'habilita_pago_adelantado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'habilita_pago_adelantado', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'liquidaci_n', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'liquidaci_n', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaci_n_ambiental', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaci_n_ambiental', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaci_n_ambiental', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaciones_postconsumo', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaciones_postconsumo', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'obligaciones_postconsumo', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'reversion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'reversion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'reversion', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'origen_de_los_recursos', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'origen_de_los_recursos', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'origen_de_los_recursos', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'destino_gasto', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'destino_gasto', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'destino_gasto', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_del_contrato', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_de_pago_adelantado', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_de_pago_adelantado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_de_pago_adelantado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_de_pago_adelantado', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_facturado', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_facturado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_facturado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_pago', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_pago', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_pago', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pagado', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pagado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pagado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_amortizado', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_amortizado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_amortizado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_amortizado', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_ejecucion', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_ejecucion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'valor_pendiente_de_ejecucion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_bpin', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_bpin', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'estado_bpin', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'c_digo_bpin', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'c_digo_bpin', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'c_digo_bpin', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'anno_bpin', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'anno_bpin', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'anno_bpin', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_cdp', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_cdp', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_cdp', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_vigencia', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_vigencia', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_vigencia', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'saldo_vigencia', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'espostconflicto', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'espostconflicto', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'espostconflicto', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'dias_adicionados', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'dias_adicionados', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'dias_adicionados', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'dias_adicionados', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'puntos_del_acuerdo', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'puntos_del_acuerdo', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'puntos_del_acuerdo', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'pilares_del_acuerdo', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'pilares_del_acuerdo', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'pilares_del_acuerdo', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'urlproceso', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'urlproceso', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_representante_legal', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nacionalidad_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nacionalidad_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'domicilio_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'domicilio_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'domicilio_representante_legal', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_identificaci_n_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_identificaci_n_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'identificaci_n_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'identificaci_n_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'g_nero_representante_legal', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'g_nero_representante_legal', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'g_nero_representante_legal', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'presupuesto_general_de_la_nacion_pgn', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'presupuesto_general_de_la_nacion_pgn', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'presupuesto_general_de_la_nacion_pgn', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'presupuesto_general_de_la_nacion_pgn', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_participaciones', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_participaciones', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_participaciones', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_regal_as', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_regal_as', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_regal_as', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'sistema_general_de_regal_as', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_de_credito', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_de_credito', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_de_credito', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_de_credito', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'recursos_propios', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ultima_actualizacion', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ultima_actualizacion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ultima_actualizacion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'ultima_actualizacion', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_entidad', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_entidad', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_entidad', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_proveedor', 'issue': "Expected type 'integer' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_proveedor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'codigo_proveedor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_inicio_liquidacion', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_inicio_liquidacion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_inicio_liquidacion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_fin_liquidacion', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_fin_liquidacion', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_fin_liquidacion', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'objeto_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'objeto_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'objeto_del_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'duraci_n_del_contrato', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'duraci_n_del_contrato', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'duraci_n_del_contrato', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_del_banco', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_del_banco', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_del_banco', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_cuenta', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_cuenta', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_cuenta', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_cuenta', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_cuenta', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'el_contrato_puede_ser_prorrogado', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'el_contrato_puede_ser_prorrogado', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'el_contrato_puede_ser_prorrogado', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_del_gasto', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_del_gasto', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_del_gasto', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_del_gasto', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_del_gasto', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_del_gasto', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_ordenador_del_gasto', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_ordenador_del_gasto', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_supervisor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_supervisor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_supervisor', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_supervisor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_supervisor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_supervisor', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_supervisor', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_supervisor', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_de_pago', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_de_pago', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'nombre_ordenador_de_pago', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_de_pago', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_de_pago', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'tipo_de_documento_ordenador_de_pago', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_ordenador_de_pago', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_ordenador_de_pago', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'n_mero_de_documento_ordenador_de_pago', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_notificaci_n_de_prorrogaci_n', 'issue': "Expected type 'datetime' but got 'string'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_notificaci_n_de_prorrogaci_n', 'issue': "Missing mandatory rule 'no_nulls'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_notificaci_n_de_prorrogaci_n', 'issue': "Missing mandatory rule 'valid_date_format'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': 'fecha_de_notificaci_n_de_prorrogaci_n', 'issue': "Security level 'none' is below baseline 'masked'.", 'severity': 'warning', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}
#  - {'field': '__global__', 'issue': "Dataset risk level 'high' exceeds accepted 'medium'.", 'severity': 'error', 'execution_id': '3d56820c-b07e-472c-b0ce-1ba0cacae657', 'timestamp': '2025-03-29T22:31:23.990960'}

# %%
meta_logger.log({
    "step": "policy_application",
    "policy_name": "s2_contracts.yaml",
    "status": "applied"
})
# Out:
# 2025-03-29 18:38:37,882 - ingestion.base.metadata_logger - DEBUG - Logged metadata: {'step': 'policy_application', 'policy_name': 's2_contracts.yaml', 'status': 'applied', 'uuid': 'b7d0d869-248f-45dd-9565-c3c59bcebf94', 'timestamp': '2025-03-29T22:38:37.882044+00:00'}

# %%
metrics_engine = MetricsEngine(df, "s2_contracts.yaml")
metrics_dict = metrics_engine.generate_quality_metrics()

# %%
meta_logger.log({
    "step": "governance_metrics",
    "status": "executed"
})

# %%
metrics_dict
# Out:
# {'nombre_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'nit_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': np.float64(1101537680.46),
#   'median': np.float64(890751787.5),
#   'std': np.float64(1329078600.2603405),
#   'percentiles': {'25': np.float64(842000004.0),
#    '50': np.float64(890751787.5),
#    '75': np.float64(890980093.0)},
#   'skewness': np.float64(5.615650057510579),
#   'outlier_percentage': np.float64(3.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(18.54349942489421)},
#  'departamento': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 87.0,
#   'uniqueness_rate': 0.13,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.13,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(82.6)},
#  'ciudad': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'localizaci_n': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'orden': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'sector': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'rama': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'entidad_centralizada': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'proceso_de_compra': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'id_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'referencia_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 3.0,
#   'uniqueness_rate': 0.97,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.97,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.9)},
#  'estado_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'codigo_de_categoria_principal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 54.0,
#   'uniqueness_rate': 0.46,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.46,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(89.2)},
#  'descripcion_del_proceso': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 7.000000000000001,
#   'uniqueness_rate': 0.93,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.93,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(92.1)},
#  'tipo_de_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.05,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(81.0)},
#  'modalidad_de_contratacion': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'justificacion_modalidad_de': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.05,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(81.0)},
#  'fecha_de_firma': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'fecha_de_inicio_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(61.0)},
#  'fecha_de_fin_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 82.0,
#   'uniqueness_rate': 0.18,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(63.599999999999994)},
#  'condiciones_de_entrega': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'tipodocproveedor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'documento_proveedor': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': np.float64(722677927.92),
#   'median': np.float64(901348707.0),
#   'std': np.float64(454989818.733051),
#   'percentiles': {'25': np.float64(75096115.0),
#    '50': np.float64(901348707.0),
#    '75': np.float64(1090844982.75)},
#   'skewness': np.float64(0.7605618031663014),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.0)},
#  'proveedor_adjudicado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'es_grupo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'es_pyme': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'habilita_pago_adelantado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'liquidaci_n': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'obligaci_n_ambiental': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'obligaciones_postconsumo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'reversion': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'origen_de_los_recursos': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'destino_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'valor_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 6.0,
#   'uniqueness_rate': 0.94,
#   'contains_outliers': False,
#   'mean': np.float64(214863592.31),
#   'median': np.float64(30557928.0),
#   'std': np.float64(628408232.6620088),
#   'percentiles': {'25': np.float64(10800000.0),
#    '50': np.float64(30557928.0),
#    '75': np.float64(87000000.0)},
#   'skewness': np.float64(4.808620986848929),
#   'outlier_percentage': np.float64(17.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(32.213790131510706)},
#  'valor_de_pago_adelantado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'valor_facturado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 54.0,
#   'uniqueness_rate': 0.46,
#   'contains_outliers': False,
#   'mean': np.float64(157163309.2),
#   'median': np.float64(0.0),
#   'std': np.float64(624388299.167977),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(13299750.0)},
#   'skewness': np.float64(5.10676192968314),
#   'outlier_percentage': np.float64(15.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(20.632380703168604)},
#  'valor_pendiente_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 28.000000000000004,
#   'uniqueness_rate': 0.72,
#   'contains_outliers': False,
#   'mean': np.float64(58017646.79),
#   'median': np.float64(10382400.0),
#   'std': np.float64(136373744.20644438),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(10382400.0),
#    '75': np.float64(48821291.25)},
#   'skewness': np.float64(4.679541829386796),
#   'outlier_percentage': np.float64(13.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(31.104581706132038)},
#  'valor_pagado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 56.00000000000001,
#   'uniqueness_rate': 0.44,
#   'contains_outliers': False,
#   'mean': np.float64(156845945.51),
#   'median': np.float64(0.0),
#   'std': np.float64(624462858.4706677),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(10996500.0)},
#   'skewness': np.float64(5.106403282011801),
#   'outlier_percentage': np.float64(16.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(19.73596717988199)},
#  'valor_amortizado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'valor_pendiente_de': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'valor_pendiente_de_ejecucion': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 28.000000000000004,
#   'uniqueness_rate': 0.72,
#   'contains_outliers': False,
#   'mean': np.float64(58017646.79),
#   'median': np.float64(10382400.0),
#   'std': np.float64(136373744.20644438),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(10382400.0),
#    '75': np.float64(48821291.25)},
#   'skewness': np.float64(4.679541829386796),
#   'outlier_percentage': np.float64(13.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(31.104581706132038)},
#  'estado_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'c_digo_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'anno_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'saldo_cdp': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 47.0,
#   'uniqueness_rate': 0.53,
#   'contains_outliers': False,
#   'mean': np.float64(167559356.74),
#   'median': np.float64(7200000.0),
#   'std': np.float64(598842264.6377865),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(7200000.0),
#    '75': np.float64(40964745.0)},
#   'skewness': np.float64(5.093577591460604),
#   'outlier_percentage': np.float64(15.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(22.16422408539396)},
#  'saldo_vigencia': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'espostconflicto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'dias_adicionados': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 94.0,
#   'uniqueness_rate': 0.06,
#   'contains_outliers': False,
#   'mean': np.float64(4.04),
#   'median': np.float64(0.0),
#   'std': np.float64(14.742859939371302),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(3.569206234808937),
#   'outlier_percentage': np.float64(8.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(31.507937651910627)},
#  'puntos_del_acuerdo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'pilares_del_acuerdo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'urlproceso': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'nombre_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'nacionalidad_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'domicilio_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 56.99999999999999,
#   'uniqueness_rate': 0.43,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.43,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(88.6)},
#  'tipo_de_identificaci_n_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'identificaci_n_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 30.0,
#   'uniqueness_rate': 0.7,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.7,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(94.0)},
#  'g_nero_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'presupuesto_general_de_la_nacion_pgn': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'sistema_general_de_participaciones': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 91.0,
#   'uniqueness_rate': 0.09,
#   'contains_outliers': False,
#   'mean': np.float64(4383088.57),
#   'median': np.float64(0.0),
#   'std': np.float64(20738743.722822387),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(6.863183942825543),
#   'outlier_percentage': np.float64(8.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': 0},
#  'sistema_general_de_regal_as': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 79.0,
#   'uniqueness_rate': 0.21,
#   'contains_outliers': False,
#   'mean': np.float64(102585408.03),
#   'median': np.float64(0.0),
#   'std': np.float64(559086697.7549158),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(6.707637873749376),
#   'outlier_percentage': np.float64(20.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': 0},
#  'recursos_de_credito': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'recursos_propios': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 72.0,
#   'uniqueness_rate': 0.28,
#   'contains_outliers': False,
#   'mean': np.float64(51081989.57),
#   'median': np.float64(0.0),
#   'std': np.float64(237017011.7510147),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(4650000.0)},
#   'skewness': np.float64(6.095863409051045),
#   'outlier_percentage': np.float64(16.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(6.641365909489549)},
#  'ultima_actualizacion': {'null_percentage': np.float64(26.0),
#   'type_match': False,
#   'duplicate_percentage': 47.0,
#   'uniqueness_rate': 0.53,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(57.6)},
#  'codigo_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': np.float64(705746001.97),
#   'median': np.float64(704403419.0),
#   'std': np.float64(4279122.517907342),
#   'percentiles': {'25': np.float64(703294033.0),
#    '50': np.float64(704403419.0),
#    '75': np.float64(705985851.0)},
#   'skewness': np.float64(1.6196510688063628),
#   'outlier_percentage': np.float64(19.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(50.50348931193638)},
#  'codigo_proveedor': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': np.float64(716512540.5),
#   'median': np.float64(718910565.5),
#   'std': np.float64(5400192.6433720505),
#   'percentiles': {'25': np.float64(716206990.0),
#    '50': np.float64(718910565.5),
#    '75': np.float64(719961818.5)},
#   'skewness': np.float64(1.5564422407554728),
#   'outlier_percentage': np.float64(17.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(65.93557759244527)},
#  'fecha_inicio_liquidacion': {'null_percentage': np.float64(50.0),
#   'type_match': False,
#   'duplicate_percentage': 87.0,
#   'uniqueness_rate': 0.13,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(37.599999999999994)},
#  'fecha_fin_liquidacion': {'null_percentage': np.float64(50.0),
#   'type_match': False,
#   'duplicate_percentage': 75.0,
#   'uniqueness_rate': 0.25,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(40.0)},
#  'objeto_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 7.000000000000001,
#   'uniqueness_rate': 0.93,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.93,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(92.1)},
#  'duraci_n_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 79.0,
#   'uniqueness_rate': 0.21,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.21,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(84.2)},
#  'nombre_del_banco': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 88.0,
#   'uniqueness_rate': 0.12,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.12,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(82.4)},
#  'tipo_de_cuenta': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'n_mero_de_cuenta': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 56.99999999999999,
#   'uniqueness_rate': 0.43,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.43,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(88.6)},
#  'el_contrato_puede_ser_prorrogado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'nombre_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 72.0,
#   'uniqueness_rate': 0.28,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.28,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(85.6)},
#  'tipo_de_documento_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'n_mero_de_documento_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 72.0,
#   'uniqueness_rate': 0.28,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.28,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(85.6)},
#  'nombre_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 64.0,
#   'uniqueness_rate': 0.36,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.36,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(87.2)},
#  'tipo_de_documento_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'n_mero_de_documento_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 65.0,
#   'uniqueness_rate': 0.35,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.35,
#   'security_compliant': np.False_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(87.0)},
#  'nombre_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'tipo_de_documento_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'n_mero_de_documento_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'fecha_de_notificaci_n_de_prorrogaci_n': {'null_percentage': np.float64(77.0),
#   'type_match': False,
#   'duplicate_percentage': 88.0,
#   'uniqueness_rate': 0.12,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(23.9)},
#  'global': {'average_quality_score': np.float64(69.75396935768111),
#   'total_fields': 85}}

# %%
remediation_engine = RemediationEngine(df, "s2_contracts.yaml")
df_procesed = remediation_engine.run_remediation()

# %%
df_procesed.head()
# Out:
#                                       nombre_entidad   nit_entidad  \
# 0  SE9TUElUQUwgU0FOIEpVQU4gREUgRElPUyBERSBIT05EQS...  ODkwNzAwNjY2
# 1  SE9TUElUQUwgREUgQ0FTVElMTEEgTEEgTlVFVkEgRU1QUk...  OTAwMDA0MDU5
# 2  SE9TUElUQUwgU0FOIEpVQU4gREUgRElPUyBERSBIT05EQS...  ODkwNzAwNjY2
# 3  RU1QUkVTQSBTT0NJQUwgREVMIEVTVEFETyBIT1NQSVRBTC...  OTY0NDUwMjI2
# 4                       TVVOSUNJUElPIERFIElUQUdVSQ==  ODkwOTgwMDkz
#
#   departamento             ciudad                          localizaci_n  \
# 0       Tolima              Honda            Colombia,  Tolima ,  Honda
# 1         Meta  Castilla La Nueva  Colombia,  Meta ,  Castilla La Nueva
# 2       Tolima              Honda            Colombia,  Tolima ,  Honda
# 3    Antioquia             Amalfi        Colombia,  Antioquia ,  Amalfi
# 4    Antioquia             Itagui        Colombia,  Antioquia ,  Itagui
#
#          orden                         sector                  rama  \
# 0  Territorial      Salud y Protección Social  Corporación Autónoma
# 1  Territorial      Salud y Protección Social  Corporación Autónoma
# 2  Territorial      Salud y Protección Social  Corporación Autónoma
# 3  Territorial      Salud y Protección Social             Ejecutivo
# 4  Territorial  Vivienda, Ciudad y Territorio             Ejecutivo
#
#    entidad_centralizada         proceso_de_compra  ...  \
# 0  RGVzY2VudHJhbGl6YWRh  Q08xLkJET1MuMzY4MTIyMw==  ...
# 1  RGVzY2VudHJhbGl6YWRh  Q08xLkJET1MuMzY5MDUyOA==  ...
# 2  RGVzY2VudHJhbGl6YWRh  Q08xLkJET1MuMzY3NzYyNA==  ...
# 3  RGVzY2VudHJhbGl6YWRh  Q08xLkJET1MuMzY4ODM2NQ==  ...
# 4      Q2VudHJhbGl6YWRh  Q08xLkJET1MuMzY3MTQ0MQ==  ...
#
#          nombre_ordenador_del_gasto tipo_de_documento_ordenador_del_gasto  \
# 0    MANUEL ALFONSO GONZaLEZ CANTOR                  Cédula de Ciudadanía
# 1        ROSA MARIA JIMENEZ BAQUERO                  Cédula de Ciudadanía
# 2    MANUEL ALFONSO GONZaLEZ CANTOR                  Cédula de Ciudadanía
# 3  LICINIA DEL CARMEN RAVE BERMUDEZ                  Cédula de Ciudadanía
# 4                       No definido                           No definido
#
#   n_mero_de_documento_ordenador_del_gasto               nombre_supervisor  \
# 0                            NzkzOTMxNzI=     MARTHA LUCIA OSORIO RAMIREZ
# 1                            NDAzNzA4OTM=        LUIS ENRIQUE BARON TELLO
# 2                            NzkzOTMxNzI=  ANGELA MARLEN SALGUERO RAMIREZ
# 3                            NDI4NzY1MTY=      ANGEL ERNESTO FRANCO HENAO
# 4                        Tm8gZGVmaW5pZG8=                     No definido
#
#   tipo_de_documento_supervisor n_mero_de_documento_supervisor  \
# 0         Cédula de Ciudadanía                   MzgyODEzMTg=
# 1         Cédula de Ciudadanía               MTEyMTgyNzM1Mw==
# 2         Cédula de Ciudadanía               MTExMDUyNjM2NQ==
# 3         Cédula de Ciudadanía                   NzAyNTIxOTY=
# 4                  No definido               Tm8gZGVmaW5pZG8=
#
#   nombre_ordenador_de_pago tipo_de_documento_ordenador_de_pago  \
# 0              No definido                         No definido
# 1              No definido                         No definido
# 2              No definido                         No definido
# 3              No definido                         No definido
# 4              No definido                         No definido
#
#   n_mero_de_documento_ordenador_de_pago fecha_de_notificaci_n_de_prorrogaci_n
# 0                           No definido                                   NaT
# 1                           No definido                                   NaT
# 2                           No definido                                   NaT
# 3                           No definido                                   NaT
# 4                           No definido                                   NaT
#
# [5 rows x 85 columns]

# %%
meta_logger.log({
    "step": "remediation",
    "status": "executed"
})

# %%
metrics_engine_procesed = MetricsEngine(df_procesed, "s2_contracts.yaml")
metrics_dict_df_processed = metrics_engine_procesed.generate_quality_metrics()
# Out:
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Espacios de trabajo\personal-library\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
metrics_dict_df_processed
# Out:
# {'nombre_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'nit_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 70.0,
#   'uniqueness_rate': 0.3,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(66.0)},
#  'departamento': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 87.0,
#   'uniqueness_rate': 0.13,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.13,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(82.6)},
#  'ciudad': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'localizaci_n': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 69.0,
#   'uniqueness_rate': 0.31,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.31,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(86.2)},
#  'orden': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'sector': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'rama': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'entidad_centralizada': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'proceso_de_compra': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'id_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'referencia_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 3.0,
#   'uniqueness_rate': 0.97,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.97,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.9)},
#  'estado_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'codigo_de_categoria_principal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 54.0,
#   'uniqueness_rate': 0.46,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.46,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(89.2)},
#  'descripcion_del_proceso': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 7.000000000000001,
#   'uniqueness_rate': 0.93,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.93,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(92.1)},
#  'tipo_de_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.05,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(81.0)},
#  'modalidad_de_contratacion': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'justificacion_modalidad_de': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.05,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(81.0)},
#  'fecha_de_firma': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': 0,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'fecha_de_inicio_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 95.0,
#   'uniqueness_rate': 0.05,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': 0,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(81.0)},
#  'fecha_de_fin_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 82.0,
#   'uniqueness_rate': 0.18,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': 0,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(83.6)},
#  'condiciones_de_entrega': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'tipodocproveedor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'documento_proveedor': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.0)},
#  'proveedor_adjudicado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'es_grupo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'es_pyme': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'habilita_pago_adelantado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'liquidaci_n': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'obligaci_n_ambiental': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'obligaciones_postconsumo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'reversion': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'origen_de_los_recursos': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'destino_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'valor_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 21.0,
#   'uniqueness_rate': 0.79,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(75.8)},
#  'valor_de_pago_adelantado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'valor_facturado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 68.0,
#   'uniqueness_rate': 0.32,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(66.4)},
#  'valor_pendiente_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 40.0,
#   'uniqueness_rate': 0.6,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(72.0)},
#  'valor_pagado': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 71.0,
#   'uniqueness_rate': 0.29,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(65.8)},
#  'valor_amortizado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'valor_pendiente_de': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'valor_pendiente_de_ejecucion': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 40.0,
#   'uniqueness_rate': 0.6,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(72.0)},
#  'estado_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'c_digo_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'anno_bpin': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'saldo_cdp': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 61.0,
#   'uniqueness_rate': 0.39,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(67.8)},
#  'saldo_vigencia': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'espostconflicto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'dias_adicionados': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'puntos_del_acuerdo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'pilares_del_acuerdo': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'urlproceso': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'nombre_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 0.0,
#   'uniqueness_rate': 1.0,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 1.0,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(90.0)},
#  'nacionalidad_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'domicilio_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 56.99999999999999,
#   'uniqueness_rate': 0.43,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.43,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(88.6)},
#  'tipo_de_identificaci_n_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'identificaci_n_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 30.0,
#   'uniqueness_rate': 0.7,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.7,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(94.0)},
#  'g_nero_representante_legal': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 96.0,
#   'uniqueness_rate': 0.04,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.04,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.8)},
#  'presupuesto_general_de_la_nacion_pgn': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'sistema_general_de_participaciones': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'sistema_general_de_regal_as': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(60.2)},
#  'recursos_de_credito': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': np.float64(0.0),
#   'median': np.float64(0.0),
#   'std': np.float64(0.0),
#   'percentiles': {'25': np.float64(0.0),
#    '50': np.float64(0.0),
#    '75': np.float64(0.0)},
#   'skewness': np.float64(0.0),
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'recursos_propios': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 87.0,
#   'uniqueness_rate': 0.13,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(62.599999999999994)},
#  'ultima_actualizacion': {'null_percentage': np.float64(26.0),
#   'type_match': True,
#   'duplicate_percentage': 47.0,
#   'uniqueness_rate': 0.53,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': np.float64(32.5),
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': 0},
#  'codigo_entidad': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 73.0,
#   'uniqueness_rate': 0.27,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(65.4)},
#  'codigo_proveedor': {'null_percentage': np.float64(0.0),
#   'type_match': False,
#   'duplicate_percentage': 16.0,
#   'uniqueness_rate': 0.84,
#   'contains_outliers': False,
#   'mean': nan,
#   'median': np.float64(nan),
#   'std': np.float64(nan),
#   'percentiles': {'25': np.float64(nan),
#    '50': np.float64(nan),
#    '75': np.float64(nan)},
#   'skewness': nan,
#   'outlier_percentage': np.float64(0.0),
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(76.8)},
#  'fecha_inicio_liquidacion': {'null_percentage': np.float64(50.0),
#   'type_match': False,
#   'duplicate_percentage': 87.0,
#   'uniqueness_rate': 0.13,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(37.599999999999994)},
#  'fecha_fin_liquidacion': {'null_percentage': np.float64(50.0),
#   'type_match': False,
#   'duplicate_percentage': 75.0,
#   'uniqueness_rate': 0.25,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(40.0)},
#  'objeto_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 7.000000000000001,
#   'uniqueness_rate': 0.93,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.93,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(92.1)},
#  'duraci_n_del_contrato': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 79.0,
#   'uniqueness_rate': 0.21,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.21,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(84.2)},
#  'nombre_del_banco': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 88.0,
#   'uniqueness_rate': 0.12,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.12,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(82.4)},
#  'tipo_de_cuenta': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 97.0,
#   'uniqueness_rate': 0.03,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.03,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.6)},
#  'n_mero_de_cuenta': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 56.99999999999999,
#   'uniqueness_rate': 0.43,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.43,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(88.6)},
#  'el_contrato_puede_ser_prorrogado': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'nombre_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 72.0,
#   'uniqueness_rate': 0.28,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.28,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(85.6)},
#  'tipo_de_documento_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'n_mero_de_documento_ordenador_del_gasto': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 72.0,
#   'uniqueness_rate': 0.28,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.28,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(85.6)},
#  'nombre_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 64.0,
#   'uniqueness_rate': 0.36,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.36,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(87.2)},
#  'tipo_de_documento_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 98.0,
#   'uniqueness_rate': 0.02,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.02,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.4)},
#  'n_mero_de_documento_supervisor': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 65.0,
#   'uniqueness_rate': 0.35,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.35,
#   'security_compliant': np.True_,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(87.0)},
#  'nombre_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'tipo_de_documento_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'n_mero_de_documento_ordenador_de_pago': {'null_percentage': np.float64(0.0),
#   'type_match': True,
#   'duplicate_percentage': 99.0,
#   'uniqueness_rate': 0.01,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': None,
#   'cardinality_ratio': 0.01,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': np.float64(80.2)},
#  'fecha_de_notificaci_n_de_prorrogaci_n': {'null_percentage': np.float64(77.0),
#   'type_match': True,
#   'duplicate_percentage': 88.0,
#   'uniqueness_rate': 0.12,
#   'contains_outliers': False,
#   'mean': None,
#   'median': None,
#   'std': None,
#   'skewness': None,
#   'percentiles': {},
#   'outlier_percentage': None,
#   'temporal_anomaly': np.float64(178.0),
#   'cardinality_ratio': None,
#   'security_compliant': True,
#   'relational_compliance': 'n/a',
#   'field_quality_score': 0},
#  'global': {'average_quality_score': np.float64(77.74941176470588),
#   'total_fields': 85}}

# %%
meta_logger.log({
    "step": "governance_metrics",
    "status": "executed"
})

# %%
engine = IntelligentImprovementEngine(metrics_dict_df_processed, metrics_engine.policy)
recommendations = engine.generate_improvement_recommendations()

print("Global Recommendations:")
for rec in recommendations["global"]:
    print(" -", rec)
for field, recs in recommendations["fields"].items():
    print(f"Field '{field}':")
    for r in recs:
        print("   -", r)
# Out:
# Global Recommendations:
#  - La calidad global es baja; se recomienda una revisión integral de la ingesta.
# Field 'nombre_entidad':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 13.8 puntos.
# Field 'nit_entidad':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 14.0 puntos.
# Field 'departamento':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 17.4 puntos.
# Field 'ciudad':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 13.8 puntos.
# Field 'localizaci_n':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 13.8 puntos.
# Field 'orden':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'sector':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.4 puntos.
# Field 'rama':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'entidad_centralizada':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'proceso_de_compra':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 10.0 puntos.
# Field 'id_contrato':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 10.0 puntos.
# Field 'referencia_del_contrato':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 8.5 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 0.6 puntos.
# Field 'estado_contrato':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.2 puntos.
# Field 'codigo_de_categoria_principal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 10.8 puntos.
# Field 'descripcion_del_proceso':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 6.5 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 1.4 puntos.
# Field 'tipo_de_contrato':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.0 puntos.
# Field 'modalidad_de_contratacion':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.2 puntos.
# Field 'justificacion_modalidad_de':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.0 puntos.
# Field 'fecha_de_firma':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'fecha_de_inicio_del_contrato':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.0 puntos.
# Field 'fecha_de_fin_del_contrato':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 16.4 puntos.
# Field 'condiciones_de_entrega':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.4 puntos.
# Field 'tipodocproveedor':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'documento_proveedor':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
# Field 'proveedor_adjudicado':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 10.0 puntos.
# Field 'es_grupo':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'es_pyme':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'habilita_pago_adelantado':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'liquidaci_n':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'obligaci_n_ambiental':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'obligaciones_postconsumo':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'reversion':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'origen_de_los_recursos':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'destino_gasto':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.4 puntos.
# Field 'valor_del_contrato':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 4.2 puntos.
# Field 'valor_de_pago_adelantado':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'valor_facturado':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 13.6 puntos.
# Field 'valor_pendiente_de_pago':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 8.0 puntos.
# Field 'valor_pagado':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 14.2 puntos.
# Field 'valor_amortizado':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'valor_pendiente_de':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'valor_pendiente_de_ejecucion':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 8.0 puntos.
# Field 'estado_bpin':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'c_digo_bpin':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'anno_bpin':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'saldo_cdp':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 12.2 puntos.
# Field 'saldo_vigencia':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'espostconflicto':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'dias_adicionados':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'puntos_del_acuerdo':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'pilares_del_acuerdo':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'urlproceso':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 10.0 puntos.
# Field 'nombre_representante_legal':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 10.0 puntos.
# Field 'nacionalidad_representante_legal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'domicilio_representante_legal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 11.4 puntos.
# Field 'tipo_de_identificaci_n_representante_legal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.2 puntos.
# Field 'identificaci_n_representante_legal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 6.0 puntos.
# Field 'g_nero_representante_legal':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.2 puntos.
# Field 'presupuesto_general_de_la_nacion_pgn':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'sistema_general_de_participaciones':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'sistema_general_de_regal_as':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'recursos_de_credito':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'recursos_propios':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 17.4 puntos.
# Field 'ultima_actualizacion':
#    - Optimizar 'temporal_anomaly' podría incrementar el score en hasta 100.0 puntos.
#    - Optimizar 'null_percentage' podría incrementar el score en hasta 13.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 9.4 puntos.
# Field 'codigo_entidad':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 14.6 puntos.
# Field 'codigo_proveedor':
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 3.2 puntos.
# Field 'fecha_inicio_liquidacion':
#    - Optimizar 'null_percentage' podría incrementar el score en hasta 25.0 puntos.
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 17.4 puntos.
# Field 'fecha_fin_liquidacion':
#    - Optimizar 'null_percentage' podría incrementar el score en hasta 25.0 puntos.
#    - Optimizar 'type_match' podría incrementar el score en hasta 20.0 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 15.0 puntos.
# Field 'objeto_del_contrato':
#    - Optimizar 'cardinality_ratio' podría incrementar el score en hasta 6.5 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 1.4 puntos.
# Field 'duraci_n_del_contrato':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 15.8 puntos.
# Field 'nombre_del_banco':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 17.6 puntos.
# Field 'tipo_de_cuenta':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.4 puntos.
# Field 'n_mero_de_cuenta':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 11.4 puntos.
# Field 'el_contrato_puede_ser_prorrogado':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'nombre_ordenador_del_gasto':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 14.4 puntos.
# Field 'tipo_de_documento_ordenador_del_gasto':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'n_mero_de_documento_ordenador_del_gasto':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 14.4 puntos.
# Field 'nombre_supervisor':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 12.8 puntos.
# Field 'tipo_de_documento_supervisor':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.6 puntos.
# Field 'n_mero_de_documento_supervisor':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 13.0 puntos.
# Field 'nombre_ordenador_de_pago':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'tipo_de_documento_ordenador_de_pago':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'n_mero_de_documento_ordenador_de_pago':
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 19.8 puntos.
# Field 'fecha_de_notificaci_n_de_prorrogaci_n':
#    - Optimizar 'temporal_anomaly' podría incrementar el score en hasta 100.0 puntos.
#    - Optimizar 'null_percentage' podría incrementar el score en hasta 38.5 puntos.
#    - Optimizar 'duplicate_percentage' podría incrementar el score en hasta 17.6 puntos.

# %% [markdown]
# **5. Registro de Metadata y Auditoría**
#
# Utilizamos la clase `MetadataLogger` para registrar la metadata del proceso de ingesta, incluyendo:
#
# - Información del loader (número de filas, estado, filtros aplicados, etc.)
#
# - Reporte de gobernanza (errores y advertencias)
#
# La metadata se guarda en un archivo Parquet para su posterior auditoría y seguimiento.

# %%
meta_logger.save()
# Out:
# 2025-03-28 08:00:49,794 - ingestion.base.metadata_logger - DEBUG - Logged metadata: {'source': 'socrata', 'status': 'success', 'error': None, 'row_count': 100, 'timestamp': '2025-03-28T12:00:49.794419+00:00', 'filters_applied': {'fecha_de_firma': ('>=', '2023-01-01')}, 'dataset_code': 'jbjy-vk9h', 'errors': [], 'warnings': ["El campo 'fecha_de_firma' tiene tipo 'object', se esperaba 'datetime64'."], 'uuid': '5c7be947-9e9c-4264-abf0-2e591051d2e8'}
# 2025-03-28 08:00:50,830 - ingestion.base.metadata_logger - INFO - Metadata log saved to reports/demo_socrata.parquet
# Metadata registrada y audit log guardado.
